# %%
import pandas as pd

pd.set_option("display.max_columns",None)

# %%
dtypes={"BankZip":str, "BusinessAge":str}
foiaData=pd.read_csv("foia-7afy2010-fy2019-asof-220930.csv", encoding="ISO-8859-1", dtype=dtypes)

# %%
# Drop rows where BankZip is M5H 1 or BankName is MISSINGMAINBANKID
bankzip_condition = foiaData["BankZip"] == "M5H 1"
bankname_condition = foiaData["BankName"] == "MISSINGMAINBANKID"
drop_condition = bankzip_condition | bankname_condition
foiaData.drop(foiaData[drop_condition].index, inplace=True)

# %%
# Drop rows with missing Borrower Name
foiaData.dropna(subset=["BorrName"],inplace=True)

# %%
# Drop the BankFDICNumber and BankNCUANumber columns
columns_to_drop=["BankFDICNumber","BankNCUANumber"]
foiaData.drop(columns_to_drop,axis=1,inplace=True)

# %%
# Create a HasFranchise column based on FranchiseNamecolumn
foiaData["HasFranchise"]=foiaData["FranchiseCode"].notna().astype(int)

# %%
# Drop the FranchiseCode and FranchiseName columns
columns_to_drop=["FranchiseCode","FranchiseName"]
foiaData.drop(columns_to_drop,axis=1,inplace=True)

# %%
# Fill missing values in NaicsCode, NaicsDescription,
# CongressionalDistrict, and BusinessType with the most frequent value
for column in ["NaicsCode", "NaicsDescription",
               "CongressionalDistrict", "BusinessType"]:
    most_frequent_value = foiaData[column].mode()[0]
    foiaData[column].fillna(most_frequent_value, inplace=True)

# %%
# Fill missing values in ProjectCounty with the most frequent value in
# ProjectState == CT
ctmode_projectstate=foiaData.loc[foiaData["ProjectState"]=="CT","ProjectCounty"].mode()[0]
foiaData["ProjectCounty"].fillna(ctmode_projectstate,inplace=True)

# %%
# Drop the BusinessAge column
foiaData.drop("BusinessAge",axis=1,inplace=True)

# %%
foiaData.head()
# Out:
#    AsOfDate Program                        BorrName  \
# 0  20220930      7A             RIVERLAND LASER LLC
# 1  20220930      7A      MARTINEZ AND MARTINEZ INC.
# 2  20220930      7A  Erez & Koby Genesis Investment
# 3  20220930      7A               Square Burger LLC
# 4  20220930      7A                 HIT FITNESS LLC
#
#                      BorrStreet     BorrCity BorrState  BorrZip  \
# 0           703 ST CROIX STREET  RIVER FALLS        WI    54022
# 1                 2430 DALY AVE  LOS ANGELES        CA    90031
# 2  10999 Reed Hartman Hwy, SUit   CINCINNATI        OH    45242
# 3           115 Kentucky Street     McKinney        TX    75069
# 4       614 A SOUTH MAIN STREET      MAULDIN        SC    29662
#
#                                     BankName            BankStreet  \
# 0              First National Community Bank          109 E 2nd St
# 1                                   Gain FCU  1800 W Magnolia Blvd
# 2  JPMorgan Chase Bank, National Association     1111 Polaris Pkwy
# 3                  American Bank of Commerce       530 E Hwy 62/82
# 4                                Truist Bank        214 N Tryon St
#
#        BankCity BankState BankZip  GrossApproval  SBAGuaranteedApproval  \
# 0  NEW RICHMOND        WI   54017         491000               441900.0
# 1       BURBANK        CA   91506          35000                31500.0
# 2      COLUMBUS        OH   43240         100500                50250.0
# 3     WOLFFORTH        TX   79382         288000               259200.0
# 4     CHARLOTTE        NC   28202          37000                18500.0
#
#   ApprovalDate  ApprovalFiscalYear FirstDisbursementDate DeliveryMethod  \
# 0   10/01/2009                2010            10/01/2009         OTH 7A
# 1   10/01/2009                2010            04/01/2011         OTH 7A
# 2   10/01/2009                2010            10/01/2009     SBA EXPRES
# 3   10/01/2009                2010            10/01/2009            PLP
# 4   10/01/2009                2010            10/01/2009     SBA EXPRES
#
#                     subpgmdesc  InitialInterestRate  TermInMonths  NaicsCode  \
# 0                     Guaranty                 6.00           120   332812.0
# 1                     Guaranty                 6.50            60   541213.0
# 2  FA$TRK (Small Loan Express)                 4.51            54   722110.0
# 3                     Guaranty                 6.00           120   722110.0
# 4  FA$TRK (Small Loan Express)                 7.50            60   812199.0
#
#                                     NaicsDescription ProjectCounty  \
# 0  Metal Coating, Engraving (except Jewelry and S...        PIERCE
# 1                           Tax Preparation Services   LOS ANGELES
# 2                           Full-Service Restaurants      HAMILTON
# 3                           Full-Service Restaurants        COLLIN
# 4                       Other Personal Care Services    GREENVILLE
#
#   ProjectState                  SBADistrictOffice  CongressionalDistrict  \
# 0           WI          WISCONSIN DISTRICT OFFICE                    7.0
# 1           CA        LOS ANGELES DISTRICT OFFICE                   28.0
# 2           OH           COLUMBUS DISTRICT OFFICE                    1.0
# 3           TX  DALLAS / FT WORTH DISTRICT OFFICE                    3.0
# 4           SC     SOUTH CAROLINA DISTRICT OFFICE                    4.0
#
#   BusinessType LoanStatus PaidInFullDate ChargeOffDate  GrossChargeOffAmount  \
# 0  CORPORATION        PIF     08/31/2016           NaN                     0
# 1  CORPORATION        PIF     04/30/2016           NaN                     0
# 2  CORPORATION        PIF     05/31/2012           NaN                     0
# 3  CORPORATION        PIF     07/31/2014           NaN                     0
# 4  CORPORATION        PIF     09/30/2013           NaN                     0
#
#    RevolverStatus  JobsSupported  HasFranchise
# 0               0             11             0
# 1               1              9             0
# 2               0             20             0
# 3               0             18             0
# 4               0              6             0

# %%
#Convert the "BankZip" column to type int
foiaData["BankZip"]=foiaData["BankZip"].astype(int)

# Convert the first column "AsOfDate" to a date
foiaData["AsOfDate"]=pd.to_datetime(foiaData["AsOfDate"], format="%Y%m%d")

#Convert other columns to datetime format
for column_to_date in ["ApprovalDate", "FirstDisbursementDate",
               "PaidInFullDate", "ChargeOffDate"]:
    foiaData[column_to_date]=pd.to_datetime(foiaData[column_to_date])

# %%
foiaData.dtypes
# Out:
# AsOfDate                 datetime64[ns]
# Program                          object
# BorrName                         object
# BorrStreet                       object
# BorrCity                         object
# BorrState                        object
# BorrZip                           int64
# BankName                         object
# BankStreet                       object
# BankCity                         object
# BankState                        object
# BankZip                           int32
# GrossApproval                     int64
# SBAGuaranteedApproval           float64
# ApprovalDate             datetime64[ns]
# ApprovalFiscalYear                int64
# FirstDisbursementDate    datetime64[ns]
# DeliveryMethod                   object
# subpgmdesc                       object
# InitialInterestRate             float64
# TermInMonths                      int64
# NaicsCode                       float64
# NaicsDescription                 object
# ProjectCounty                    object
# ProjectState                     object
# SBADistrictOffice                object
# CongressionalDistrict           float64
# BusinessType                     object
# LoanStatus                       object
# PaidInFullDate           datetime64[ns]
# ChargeOffDate            datetime64[ns]
# GrossChargeOffAmount              int64
# RevolverStatus                    int64
# JobsSupported                     int64
# HasFranchise                      int32
# dtype: object

# %%
foiaData.head(5)
# Out:
#     AsOfDate Program                        BorrName  \
# 0 2022-09-30      7A             RIVERLAND LASER LLC
# 1 2022-09-30      7A      MARTINEZ AND MARTINEZ INC.
# 2 2022-09-30      7A  Erez & Koby Genesis Investment
# 3 2022-09-30      7A               Square Burger LLC
# 4 2022-09-30      7A                 HIT FITNESS LLC
#
#                      BorrStreet     BorrCity BorrState  BorrZip  \
# 0           703 ST CROIX STREET  RIVER FALLS        WI    54022
# 1                 2430 DALY AVE  LOS ANGELES        CA    90031
# 2  10999 Reed Hartman Hwy, SUit   CINCINNATI        OH    45242
# 3           115 Kentucky Street     McKinney        TX    75069
# 4       614 A SOUTH MAIN STREET      MAULDIN        SC    29662
#
#                                     BankName            BankStreet  \
# 0              First National Community Bank          109 E 2nd St
# 1                                   Gain FCU  1800 W Magnolia Blvd
# 2  JPMorgan Chase Bank, National Association     1111 Polaris Pkwy
# 3                  American Bank of Commerce       530 E Hwy 62/82
# 4                                Truist Bank        214 N Tryon St
#
#        BankCity BankState  BankZip  GrossApproval  SBAGuaranteedApproval  \
# 0  NEW RICHMOND        WI    54017         491000               441900.0
# 1       BURBANK        CA    91506          35000                31500.0
# 2      COLUMBUS        OH    43240         100500                50250.0
# 3     WOLFFORTH        TX    79382         288000               259200.0
# 4     CHARLOTTE        NC    28202          37000                18500.0
#
#   ApprovalDate  ApprovalFiscalYear FirstDisbursementDate DeliveryMethod  \
# 0   2009-10-01                2010            2009-10-01         OTH 7A
# 1   2009-10-01                2010            2011-04-01         OTH 7A
# 2   2009-10-01                2010            2009-10-01     SBA EXPRES
# 3   2009-10-01                2010            2009-10-01            PLP
# 4   2009-10-01                2010            2009-10-01     SBA EXPRES
#
#                     subpgmdesc  InitialInterestRate  TermInMonths  NaicsCode  \
# 0                     Guaranty                 6.00           120   332812.0
# 1                     Guaranty                 6.50            60   541213.0
# 2  FA$TRK (Small Loan Express)                 4.51            54   722110.0
# 3                     Guaranty                 6.00           120   722110.0
# 4  FA$TRK (Small Loan Express)                 7.50            60   812199.0
#
#                                     NaicsDescription ProjectCounty  \
# 0  Metal Coating, Engraving (except Jewelry and S...        PIERCE
# 1                           Tax Preparation Services   LOS ANGELES
# 2                           Full-Service Restaurants      HAMILTON
# 3                           Full-Service Restaurants        COLLIN
# 4                       Other Personal Care Services    GREENVILLE
#
#   ProjectState                  SBADistrictOffice  CongressionalDistrict  \
# 0           WI          WISCONSIN DISTRICT OFFICE                    7.0
# 1           CA        LOS ANGELES DISTRICT OFFICE                   28.0
# 2           OH           COLUMBUS DISTRICT OFFICE                    1.0
# 3           TX  DALLAS / FT WORTH DISTRICT OFFICE                    3.0
# 4           SC     SOUTH CAROLINA DISTRICT OFFICE                    4.0
#
#   BusinessType LoanStatus PaidInFullDate ChargeOffDate  GrossChargeOffAmount  \
# 0  CORPORATION        PIF     2016-08-31           NaT                     0
# 1  CORPORATION        PIF     2016-04-30           NaT                     0
# 2  CORPORATION        PIF     2012-05-31           NaT                     0
# 3  CORPORATION        PIF     2014-07-31           NaT                     0
# 4  CORPORATION        PIF     2013-09-30           NaT                     0
#
#    RevolverStatus  JobsSupported  HasFranchise
# 0               0             11             0
# 1               1              9             0
# 2               0             20             0
# 3               0             18             0
# 4               0              6             0

# %%
foiaData.to_csv("foiaData.csv",index=False)

# %%
foiaData.tail()
# Out:
#          AsOfDate Program                BorrName           BorrStreet  \
# 545746 2022-09-30      7A       AML Transport LLC  7641 Division Ave S
# 545747 2022-09-30      7A  Super Swim Schools LLC   7000 E. Mayo Blvd.
# 545748 2022-09-30      7A      MASSAPEQUA 143 LLC    5129 Merrick Road
# 545749 2022-09-30      7A         Sportspedic LLC       25826 JANES CT
# 545750 2022-09-30      7A         Tulum Homes LLC   2814 SPRINGVIEW LN
#
#                BorrCity BorrState  BorrZip  \
# 545746     Grand Rapids        MI    49548
# 545747          Phoenix        AZ    85054
# 545748  Massapequa Park        NY    11762
# 545749        CHANTILLY        VA    20152
# 545750         MESQUITE        TX    75181
#
#                                       BankName         BankStreet  \
# 545746            The Huntington National Bank      17 S High St.
# 545747            KeyBank National Association      127 Public Sq
# 545748           TD Bank, National Association  2035 Limestone Rd
# 545749  Wells Fargo Bank, National Association  101 N Philips Ave
# 545750  Wells Fargo Bank, National Association  101 N Philips Ave
#
#            BankCity BankState  BankZip  GrossApproval  SBAGuaranteedApproval  \
# 545746     COLUMBUS        OH    43215          16500                 8250.0
# 545747    CLEVELAND        OH    44114        1782500              1336875.0
# 545748   WILMINGTON        DE    19808          25000                12500.0
# 545749  SIOUX FALLS        SD    57104           5000                 2500.0
# 545750  SIOUX FALLS        SD    57104          10000                 5000.0
#
#        ApprovalDate  ApprovalFiscalYear FirstDisbursementDate DeliveryMethod  \
# 545746   2019-09-30                2019            2019-10-31     SBA EXPRES
# 545747   2019-09-30                2019            2020-08-31            PLP
# 545748   2019-09-30                2019            2019-12-31     SBA EXPRES
# 545749   2019-09-30                2019                   NaT     SBA EXPRES
# 545750   2019-09-30                2019            2019-10-17     SBA EXPRES
#
#                          subpgmdesc  InitialInterestRate  TermInMonths  \
# 545746  FA$TRK (Small Loan Express)                 5.60            60
# 545747                     Guaranty                 7.25           120
# 545748  FA$TRK (Small Loan Express)                10.74           120
# 545749  FA$TRK (Small Loan Express)                10.75           120
# 545750  FA$TRK (Small Loan Express)                11.75           120
#
#         NaicsCode                                   NaicsDescription  \
# 545746   484110.0                    General Freight Trucking, Local
# 545747   611620.0                  Sports and Recreation Instruction
# 545748   713940.0            Fitness and Recreational Sports Centers
# 545749   423450.0  Medical, Dental, and Hospital Equipment and Su...
# 545750   236118.0                             Residential Remodelers
#
#        ProjectCounty ProjectState                  SBADistrictOffice  \
# 545746          KENT           MI           MICHIGAN DISTRICT OFFICE
# 545747      MARICOPA           AZ            ARIZONA DISTRICT OFFICE
# 545748        NASSAU           NY             MELVILLE BRANCH OFFICE
# 545749       LOUDOUN           VA         WASHINGTON DISTRICT OFFICE
# 545750        DALLAS           TX  DALLAS / FT WORTH DISTRICT OFFICE
#
#         CongressionalDistrict BusinessType LoanStatus PaidInFullDate  \
# 545746                    2.0  CORPORATION        PIF     2021-04-30
# 545747                    6.0  CORPORATION     EXEMPT            NaT
# 545748                    2.0  CORPORATION     EXEMPT            NaT
# 545749                   10.0  CORPORATION     COMMIT            NaT
# 545750                    5.0  CORPORATION     EXEMPT            NaT
#
#        ChargeOffDate  GrossChargeOffAmount  RevolverStatus  JobsSupported  \
# 545746           NaT                     0               0              2
# 545747           NaT                     0               0             60
# 545748           NaT                     0               1              0
# 545749           NaT                     0               1              0
# 545750           NaT                     0               1              0
#
#         HasFranchise
# 545746             0
# 545747             1
# 545748             1
# 545749             0
# 545750             0
